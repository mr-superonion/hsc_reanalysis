# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

import gc
import numpy as np
import astropy.io.fits as pyfits
import matplotlib.pylab as plt

from utils_shear_ana import pltutil
from utils_shear_ana import chainutil

# %%
nlist = ['omega_m', 's_8']
bid = 0
outlist=[]
cnamelist = []
infname0='./outputs/hscy1_chain.txt' 
outlist.append(chainutil.read_cosmosis_chain(infname0))
cnamelist.append('Year 1')
plt.close()
blind_by = None
fig=pltutil.plot_chain_corner(outlist, cnamelist, blind_by, nlist, scale = 2.1 )
# Out:
# LOADING CHAIN FROM FILE:  ./outputs/hscy1_chain.txt
